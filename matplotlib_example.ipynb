# %% [markdown]
# ## Stock Market Analysis

# %% [markdown]
# Retrieving Data from Yahoo Finance and visualizing data using Matplotlib, Pandas, and Numpy.

# %%
pip install pandas-datareader yfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.2/63.2 kB 1.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 1.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 kB 2.3 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# ...
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2022.1
#     Uninstalling pytz-2022.1:
#       Successfully uninstalled pytz-2022.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.20 requires nbformat==5.4.0, but you have nbformat 5.5.0 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

from pandas_datareader import data as pdr
import yfinance as yf

yf.pdr_override()

# CREATE TICKER INSTANCE FOR ALL
lulu = yf.Ticker('LULU')
nike = yf.Ticker('NKE')
adidas = yf.Ticker('ADS.DE')

# Specify the starting and ending dates for the time series
start = datetime(2019, 1, 1)
end  = datetime(2022, 12, 31)

# The first argument is the series we want, second and third are the starting and ending dates
#also get comparisons from competitors
lulu = pdr.get_data_yahoo('LULU', start, end)
nike = pdr.get_data_yahoo('NKE', start, end)
adidas = pdr.get_data_yahoo('ADS.DE', start, end)

# Select only the adjusted closing price data and convert them into a DataFrame

stocks = pd.DataFrame({'lulu': lulu['Adj Close'], 'nike': nike['Adj Close'], 'adidas': adidas['Adj Close']})

print(stocks)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                   lulu        nike      adidas
# Date
# 2019-01-02  123.349998   70.848518  172.520828
# 2019-01-03  124.360001   69.595345  172.099823
# 2019-01-04  128.550003   71.412941  178.742447
# 2019-01-07  134.100006   72.436546  177.479416
# 2019-01-08  135.860001   73.402763  181.783081
# ...                ...         ...         ...
# 2022-12-23  311.540009  115.539154  125.332886
# 2022-12-27  315.040009  116.841141  125.810867
# 2022-12-28  308.959991  114.276924  125.253220
# 2022-12-29  316.820007  116.632423  127.842331
# 2022-12-30  320.380005  116.294510  126.926178
#
# [1033 rows x 3 columns]

# %%
#matplotlib inline
import matplotlib.pyplot as plt

lulu = pdr.get_data_yahoo('LULU', '2019-12-31', '2022-12-31')
close_price = pd.DataFrame({'lulu': lulu['Adj Close']})
print(close_price)
close_price.plot();
plt.title('Lululemon Daily Closing Price from Dec 2019 - Dec 2022');
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   lulu
# Date
# 2019-12-31  231.669998
# 2020-01-02  233.419998
# 2020-01-03  232.639999
# 2020-01-06  235.429993
# 2020-01-07  233.699997
# ...                ...
# 2022-12-23  311.540009
# 2022-12-27  315.040009
# 2022-12-28  308.959991
# 2022-12-29  316.820007
# 2022-12-30  320.380005
#
# [757 rows x 1 columns]

# %%
# Get the data for the stock AAPL
data = yf.download('lulu','2022-1-1','2023-1-1')

# Import the plotting library
import matplotlib.pyplot as plt
# %matplotlib inline

# Plot the close price of the Lulu
data['Adj Close'].plot()
plt.title('lulu Daily Closing Price from Jan 2022 - Jan 2023')
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
yf.download('lulu nke ADS.DE ',start='2019-12-31',end='2023-2-1')
# Out:
# [*********************100%***********************]  3 of 3 completed
#              Adj Close                               Close              \
#                 ADS.DE        LULU         NKE      ADS.DE        LULU
# Date
# 2019-12-31         NaN  231.669998   97.943298         NaN  231.669998
# 2020-01-02  276.475159  233.419998   98.803711  291.549988  233.419998
# 2020-01-03  276.854462  232.639999   98.533043  291.950012  232.639999
# 2020-01-06  274.673431  235.429993   98.446014  289.649994  235.429993
# 2020-01-07  279.509705  233.699997   98.397682  294.750000  233.699997
# ...                ...         ...         ...         ...         ...
# 2023-01-25  144.890625  309.519989  126.044518  145.500000  309.519989
# 2023-01-26  144.671555  309.589996  126.750175  145.279999  309.589996
# 2023-01-27  144.671555  310.850006  126.750175  145.279999  310.850006
# 2023-01-30  146.703018  302.589996  125.597275  147.320007  302.589996
# ...

# %%
# Plot the respective graphs
stocks.plot(title='Plot of LULU, NKE, and ADS.GE stock prices', figsize=(14,10), grid=True)
# Out:
# <AxesSubplot:title={'center':'Plot of LULU, NKE, and ADS.GE stock prices'}, xlabel='Date'>

# %%
# Include a secondary axis for better visualization
stocks.plot(secondary_y = ['gme'], title='Plot of LULU, NKE, and ADS.GE stock prices', figsize=(14,10), grid=True)
# Out:
# <AxesSubplot:title={'center':'Plot of LULU, NKE, and ADS.GE stock prices'}, xlabel='Date'>

# %%
# Create a Pandas Excel writer
writer = pd.ExcelWriter('stocks.xlsx', engine = 'xlsxwriter')

# Convert the dataframe
stocks.to_excel(writer, sheet_name = 'Athletic Wear Analysis')

# Close the Pandas Excel writer and output the Excel file
writer.save()
